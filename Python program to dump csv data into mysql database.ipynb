# %%
# Importing the excel data into dataframe format
import pandas as pd
data=pd.read_csv(r"https://raw.githubusercontent.com/alvee42/old_titanic_dataset/main/train.csv")
df=pd.DataFrame(data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Downloading the module
# !pip install pymysql

# %%
# !pip install sqlalchemy

# %%
# Establishing the connection using sqlalchemy
from sqlalchemy import create_engine
user = 'root'
password = 'admin'
host = 'localhost'
port = 3306
database = 'Aman_db'
mydb=create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")
print("Connection established at",mydb)
# Out:
# Connection established at Engine(mysql+pymysql://root:***@localhost:3306/Aman_db)

# %%
# # Now dumping all the data into mysql database
data.to_sql(con=mydb,name="titanic",index=False, if_exists="append")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
# import mysql.connector as connection
# try:
#     db=connection.connect(host="localhost",database="Aman_db",user="root",passwd='admin')
#     print(db)
#     query="select * from bank_details limit 100"
#     cursor=db.cursor()
#     cursor.execute(query)
#     print(cursor.fetchall())
# except Exception as e:
#     mydb.close()
#     print(e)

# %%
# query="select count(*) from bank_details"
# cursor=db.cursor()
# cursor.execute(query)
# print("The number of records present is",cursor.fetchall())
# Out:
# The number of records present is [(45211,)]

# %%
import mysql.connector as connection
try:
    db=connection.connect(host="localhost",database="Aman_db",user="root",passwd='admin')
    print(db)
    query=r"""load data infile 'C:\Users\Aman\Downloads\bank-full.csv'
              into table bank_details_1 
              fields terminated by ';' 
              enclosed by '"' 
              lines terminated by '\n' 
              ignore 1 rows;"""
    cursor=db.cursor()
    cursor.execute(query)
    print(cursor.fetchall())
except Exception as e:
    db.close()
    print(e)
# Out:
# ...
# 1146 (42S02): Table 'aman_db.bank_details_1' doesn't exist
