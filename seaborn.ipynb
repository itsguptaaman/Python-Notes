# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x='tip', y='total_bill')

# %%
sns.relplot(data=tips,x='tip', y='total_bill', hue='smoker')

# %%
sns.relplot(data=tips,x='tip', y='total_bill', hue='day', style='smoker', size='size')

# %%
sns.relplot(data=tips,x='tip', y='total_bill',size='size')

# %%
df=pd.DataFrame(np.random.randn(300,2), columns=['A','B'])

# %%
df
# Out:
#             A         B
# 0   -0.082121  0.813151
# 1   -0.248166 -1.008535
# 2    0.711542 -1.629615
# 3   -2.106503  0.364870
# 4   -0.091626 -0.752574
# ..        ...       ...
# 295  0.446225 -0.076493
# 296  0.797659 -2.262648
# 297  0.389051 -0.311597
# 298  1.710967 -1.448071
# 299 -1.096668 -0.147501
#
# [300 rows x 2 columns]

# %%
sns.relplot(data=df,x='A',y='B', kind='line',sort=True)

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data=iris, x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(data=tips, x='day',y='tip')

# %%
sns.catplot(data=tips, x='smoker',y='tip')

# %%
sns.catplot(data=tips, x='day',y='tip', kind='box', hue='sex')

# %%
x=np.random.randn(1000000)
x
# Out:
# array([ 1.41206765, -0.88194314,  0.6167565 , ..., -0.10231832,
#         0.07041125, -0.22888516])

# %%
sns.distplot(x)
# Out:
# C:\Users\Aman\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.jointplot( x=tips['total_bill'], y=tips['tip'])

# %%
sns.jointplot( x=tips['total_bill'], y=tips['tip'],kind='hex')

# %%
sns.pairplot(iris)

# %%
sns.lmplot(data=tips,x='total_bill', y='tip')

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips,x='total_bill', y='tip', col='day')
