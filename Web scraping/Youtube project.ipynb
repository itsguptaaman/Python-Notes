# %% [markdown]
# #### Project Challenge Given:
# Winner: 30-50k (One Plus Phone) Deadline: 12th September (19th Sept announcement on winners)
#
# Challenge PDF - https://drive.google.com/file/d/1UcmG5-QLQKz57iyY6g6v9vLrmVZ4LIWf/view?usp=sharing
#
# 1) Browse Channel Videos of Krish, Hitesh, Tulesko and MySirji Youtube Channel
#
# 2) For Latest 50 videos uploaded try to extract the below things:
#
# a) Video Link
#
# b) Comments with Commentor Name
#
# c) Download Video
#
# d) Likes for respective video
#
# e) Number of comments
#
# f) Title of Video
#
# g) Thumbnail of Video
#
# Only Comments and Thumbnail (Base 64 format) should be stored in MongoDB, others in MySQL Format
#
# 8 columns will be created including Youtube Channel Name
#
# Then front end screen: Give video link and you will get information of the table (If possible Beautify it)
#
# Deploy the app into Heroku, AWS and Azure. Sir will be expecting a link

# %%
import pandas as pd

# %%
details={'Title': 'Cracking Data Science Interview Is Easy By This Approach!! Solve this Problem', 'Likes': '606', 'Comments Number': '27 Comments', 'Video Views': '16,837 views', 'Video Link': 'https://www.youtube.com/watch?v=VC2BL_ChGeg', 'Thumbnail': 'https://i1.ytimg.com/vi/VC2BL_ChGeg/hqdefault.jpg', 'Download Link': 'https://rr1---sn-4g5ednly.googlevideo.com/videoplayback?expire=1661956978&ei=Eh8PY8CsHJyA8gPlt6TIBA&ip=154.57.3.98&id=o-AOG7osAZBPONefZOFdhlpgXdJI71TVuE2AA2tcnbkyXj&itag=22&source=youtube&requiressl=yes&mh=_-&mm=31%2C26&mn=sn-4g5ednly%2Csn-aigl6nzl&ms=au%2Conr&mv=m&mvi=1&pl=27&initcwndbps=507500&spc=lT-KhsOqHxZX2YJqAu2GBiXxe9R01zg&vprv=1&mime=video%2Fmp4&ns=cOfaDKmI95QnkdmNetBQcwAH&cnr=14&ratebypass=yes&dur=656.451&lmt=1661498403415101&mt=1661935038&fvip=4&fexp=24001373%2C24007246&c=WEB&rbqsm=fr&txp=6318224&n=HdyknQXRwBKizg&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cspc%2Cvprv%2Cmime%2Cns%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AOq0QJ8wRQIgdleDERoztg-1JsZTdMx9EHUPTTLQMv4yfqpGYc0TiowCIQCFHFzLB3ejCW_6mGoHwh1b5bviuaTqvIUEsowV809STQ%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRQIgZoHuvk4SUDAdHnxziRNYq8jp5GoclvQqvTb5GR27gnUCIQC5J5SSAa_7mNKJ9W2RwL2D-GgiqwcSTkSk4_QlgQtmSQ%3D%3D&title=Cracking%20Data%20Science%20Interview%20Is%20Easy%20By%20This%20Approach!!%20Solve%20this%20Problem'}
comments={'Pinned by Krish Naik': '5 days ago', 'Anil Bhargava': '2 scenarios: ', 'Agnik Chowdhury': 'Looking forward to learning all of these soon from you Krish..super excited to see you in class..', 'Neeshant N': "Hi Krish... thank you for the video...just wanted to know if I'm still learning DS now...can i join your stated course regarding the interview... because it's a lifetime access...but registration time may be limited right?? Just let me know please", 'Shresth Aditya': '1:12-Feature engineering and E.D.A takes around 30% of the project time', 'Zaafir C': 'Features to be dropped', 'Amit Datta': 'Hi sir - If someone is enrolled for One-Neuron, will he get access to this interview course videos as well? Or he still needs to take this course separately.', 'Piyush Jayasawal': 'Please make this Data science Interview preparation course available to tech neuron also', 'Prateek': 'Hi Krish, When will you take NLP live session ?', 'M Dodamani': 'Hi Krish,', 'Akshay Arjun Sonawane': 'Found an article ', 'Akanksha Tiwari': 'Sir please upload a full interview video please sir ', 'Bhupesh Mahara': 'Sir, is this included in Tech Neuron also ?', 'Shaista Parveen': 'Happy belated birthday Krish sir', 'Mayank Gupta': 'Really helpful... Before watching videos', 'The Algorithm': 'Big fan sir', 'PANKAJ KUMAR BARMAN': '️️ awesome sir', 'Rahul Sharma': 'Happy Birthday sir', 'shahbaz ansari': 'for pincode encoding I think min-max scaling technique is a better option because using this range will be between 0 to 1.', 'Abhishek Kulkarni': 'Pincode encoding = p(class|pincode)/len(pincode column)'}
link_of_list=[None, 'https://www.youtube.com/watch?v=MJ1vWb1rGwM', 'https://www.youtube.com/watch?v=Pp6CO2_YEDE', 'https://www.youtube.com/watch?v=-se8_ESCUTQ', 'https://www.youtube.com/watch?v=qJJEf6p8xH0', 'https://www.youtube.com/watch?v=VC2BL_ChGeg', 'https://www.youtube.com/watch?v=C0KW4MvNbIQ', 'https://www.youtube.com/watch?v=JneXvhlJW_k', 'https://www.youtube.com/shorts/uXEg8TF-2ZA', 'https://www.youtube.com/watch?v=ITyGQpyMV_w', 'https://www.youtube.com/watch?v=8-tyWaOFBPU', 'https://www.youtube.com/watch?v=uwQYAH5MC8c', 'https://www.youtube.com/watch?v=7uLzGRlXXDw', 'https://www.youtube.com/watch?v=9di4_ZJqawU', 'https://www.youtube.com/watch?v=gFwr2KxZ1pc', 'https://www.youtube.com/watch?v=g9o4_ua2Gv0', 'https://www.youtube.com/watch?v=015vL0cJfA0', 'https://www.youtube.com/watch?v=ceJyWSgiiIA', 'https://www.youtube.com/watch?v=gfvil_XC-kE', 'https://www.youtube.com/watch?v=k2pofjdxkZ8', 'https://www.youtube.com/watch?v=A3Xx8qaH8CQ', 'https://www.youtube.com/watch?v=uqbIXNKL2OA', 'https://www.youtube.com/watch?v=iyrEVohGQMM', 'https://www.youtube.com/watch?v=r_NxVNbA034', 'https://www.youtube.com/watch?v=ux1LX83ql_M', 'https://www.youtube.com/watch?v=IaDS2y6hVUc', 'https://www.youtube.com/watch?v=m_nQM_AkVfY', 'https://www.youtube.com/watch?v=-rw3TtDCVRE', 'https://www.youtube.com/watch?v=vnAN9pmgc2g', 'https://www.youtube.com/watch?v=fXfs_6o_hOs', 'https://www.youtube.com/watch?v=J_TLvwNYliM']

# %%
pd.DataFrame(details,columns=['Title','Likes','Comments Number','Video Views','Video Link',"Thumbnail"],index=[0])
# Out:
#                                                Title Likes Comments Number  \
# 0  Cracking Data Science Interview Is Easy By Thi...   606     27 Comments
#
#     Video Views                                   Video Link  \
# 0  16,837 views  https://www.youtube.com/watch?v=VC2BL_ChGeg
#
#                                            Thumbnail
# 0  https://i1.ytimg.com/vi/VC2BL_ChGeg/hqdefault.jpg

# %%
df=pd.DataFrame(columns=["Commenters Name","Comments"])

# %%
df["Commenters Name"]=comments.keys()
df["Comments"]=comments.values()

# %%
df
# Out:
#           Commenters Name                                           Comments
# 0    Pinned by Krish Naik                                         5 days ago
# 1           Anil Bhargava                                      2 scenarios:
# 2         Agnik Chowdhury  Looking forward to learning all of these soon ...
# 3              Neeshant N  Hi Krish... thank you for the video...just wan...
# 4          Shresth Aditya  1:12-Feature engineering and E.D.A takes aroun...
# 5                Zaafir C                             Features to be dropped
# 6              Amit Datta  Hi sir - If someone is enrolled for One-Neuron...
# 7        Piyush Jayasawal  Please make this Data science Interview prepar...
# 8                 Prateek    Hi Krish, When will you take NLP live session ?
# 9              M Dodamani                                          Hi Krish,
# 10  Akshay Arjun Sonawane                                  Found an article
# ...

# %%
link_of_list.append('https://www.youtube.com/shorts/uXEg8TF-2ZA')

# %%
link_of_list.insert(13,'https://www.youtube.com/shorts/uXEg8TF-2ZA')

# %%
link_of_list.insert(10,None)

# %%
link_of_list
# Out:
# [None,
#  'https://www.youtube.com/watch?v=MJ1vWb1rGwM',
#  'https://www.youtube.com/watch?v=Pp6CO2_YEDE',
#  'https://www.youtube.com/watch?v=-se8_ESCUTQ',
#  'https://www.youtube.com/shorts/uXEg8TF-2ZA',
#  'https://www.youtube.com/watch?v=qJJEf6p8xH0',
#  'https://www.youtube.com/watch?v=VC2BL_ChGeg',
#  'https://www.youtube.com/watch?v=C0KW4MvNbIQ',
#  'https://www.youtube.com/watch?v=JneXvhlJW_k',
#  'https://www.youtube.com/shorts/uXEg8TF-2ZA',
#  None,
#  'https://www.youtube.com/watch?v=ITyGQpyMV_w',
#  'https://www.youtube.com/watch?v=8-tyWaOFBPU',
#  'https://www.youtube.com/watch?v=uwQYAH5MC8c',
#  'https://www.youtube.com/shorts/uXEg8TF-2ZA',
#  'https://www.youtube.com/watch?v=7uLzGRlXXDw',
#  'https://www.youtube.com/watch?v=9di4_ZJqawU',
#  None,
#  'https://www.youtube.com/watch?v=gFwr2KxZ1pc',
#  'https://www.youtube.com/watch?v=g9o4_ua2Gv0',
#  'https://www.youtube.com/watch?v=015vL0cJfA0',
#  'https://www.youtube.com/watch?v=ceJyWSgiiIA',
# ...

# %%
def filter_links(list_link):
    list_oflinks=list_link
    link=[]
    for i in list_link:
        if i!=None:
            link.append(i)
    list_of_links=[]
    shorts=[]
    for i in link:
        x=i.split("/")
        if x[3]=='shorts':
            shorts.append(i)
        else:
            list_of_links.append(i)
    return list_of_links

# %%
l=filter_links(link_of_list)

# %%
l
# Out:
# ['https://www.youtube.com/watch?v=MJ1vWb1rGwM',
#  'https://www.youtube.com/watch?v=Pp6CO2_YEDE',
#  'https://www.youtube.com/watch?v=-se8_ESCUTQ',
#  'https://www.youtube.com/watch?v=qJJEf6p8xH0',
#  'https://www.youtube.com/watch?v=VC2BL_ChGeg',
#  'https://www.youtube.com/watch?v=C0KW4MvNbIQ',
#  'https://www.youtube.com/watch?v=JneXvhlJW_k',
#  'https://www.youtube.com/watch?v=ITyGQpyMV_w',
#  'https://www.youtube.com/watch?v=8-tyWaOFBPU',
#  'https://www.youtube.com/watch?v=uwQYAH5MC8c',
#  'https://www.youtube.com/watch?v=7uLzGRlXXDw',
#  'https://www.youtube.com/watch?v=9di4_ZJqawU',
#  'https://www.youtube.com/watch?v=gFwr2KxZ1pc',
#  'https://www.youtube.com/watch?v=g9o4_ua2Gv0',
#  'https://www.youtube.com/watch?v=015vL0cJfA0',
#  'https://www.youtube.com/watch?v=ceJyWSgiiIA',
#  'https://www.youtube.com/watch?v=gfvil_XC-kE',
#  'https://www.youtube.com/watch?v=k2pofjdxkZ8',
#  'https://www.youtube.com/watch?v=A3Xx8qaH8CQ',
#  'https://www.youtube.com/watch?v=uqbIXNKL2OA',
# ...

# %%
l="https://www.youtube.com/shorts/uXEg8TF-2ZA"
list_of_links=[]
shorts=[]
for i in link:
    x=i.split("/")
    if x[3]=='shorts':
        shorts.append(i)
    else:
        list_of_links.append(i)
print(list_of_links)
# Out:
# ['https://www.youtube.com/watch?v=MJ1vWb1rGwM', 'https://www.youtube.com/watch?v=Pp6CO2_YEDE', 'https://www.youtube.com/watch?v=-se8_ESCUTQ', 'https://www.youtube.com/watch?v=qJJEf6p8xH0', 'https://www.youtube.com/watch?v=VC2BL_ChGeg', 'https://www.youtube.com/watch?v=C0KW4MvNbIQ', 'https://www.youtube.com/watch?v=JneXvhlJW_k', 'https://www.youtube.com/watch?v=ITyGQpyMV_w', 'https://www.youtube.com/watch?v=8-tyWaOFBPU', 'https://www.youtube.com/watch?v=uwQYAH5MC8c', 'https://www.youtube.com/watch?v=7uLzGRlXXDw', 'https://www.youtube.com/watch?v=9di4_ZJqawU', 'https://www.youtube.com/watch?v=gFwr2KxZ1pc', 'https://www.youtube.com/watch?v=g9o4_ua2Gv0', 'https://www.youtube.com/watch?v=015vL0cJfA0', 'https://www.youtube.com/watch?v=ceJyWSgiiIA', 'https://www.youtube.com/watch?v=gfvil_XC-kE', 'https://www.youtube.com/watch?v=k2pofjdxkZ8', 'https://www.youtube.com/watch?v=A3Xx8qaH8CQ', 'https://www.youtube.com/watch?v=uqbIXNKL2OA', 'https://www.youtube.com/watch?v=iyrEVohGQMM', 'https://w
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Aman\PycharmProjects\youtube_scrapping\data.csv")

# %%
df
# Out:
#    Unnamed: 0         Name   Channel Id  \
# 0           0  Krish Nayak  krishnaik06
# 1           1  Krish Nayak  krishnaik06
# 2           2  Krish Nayak  krishnaik06
#
#                                                Title  Likes Comments Number  \
# 0  Solve this Data Science Interview Question Fro...    210     16 Comments
# 1  FAANG Interview DSA Series-Heap Sort,Binary Tr...    103     13 Comments
# 2  Implementing Machine Learninng Pipelines USsin...    375     28 Comments
#
#    Video Views                                   Video Link  \
# 0  6,433 views  https://www.youtube.com/watch?v=bDJkMOvhAmc
# 1  2,644 views  https://www.youtube.com/watch?v=AxALCZMo01Y
# 2  8,911 views  https://www.youtube.com/watch?v=HZ9MUzCRlzI
#
#                                            Thumbnail  \
# 0  https://i1.ytimg.com/vi/bDJkMOvhAmc/hqdefault.jpg
# 1  https://i1.ytimg.com/vi/AxALCZMo01Y/hqdefault.jpg
# 2  https://i1.ytimg.com/vi/HZ9MUzCRlzI/hqdefault.jpg
#
# ...

# %%
df2=pd.read_csv(r"C:\Users\Aman\PycharmProjects\youtube_scrapping\comments.csv")

# %%
df2
# Out:
#    Unnamed: 0                                Abhishek Chatterjee  \
# 0           0  In case of Kmeans it uses distance from centro...
# 1           1                                                NaN
# 2           2                                                NaN
#
#                                      Souvik Adhikary  \
# 0  In my opinion The way of computing clusters ma...
# 1                                                NaN
# 2                                                NaN
#
#                                   Zevier Sunil Seema   Ayan Chowdhury  \
# 0  I think it is because When you use k-means clu...  In my opinion,
# 1                                                NaN              NaN
# 2                                                NaN              NaN
#
#                                         Ayush Anchal  \
# 0  In k-means, new data point is assigned to the ...
# 1                                                NaN
# ...
