# %%
# Importin g libraries 
import numpy as np
import pandas as od
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot() #It is trying to plot a line graph for cateogrical columns
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', alpha=0.1) #alpha is for opactity of colour
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', alpha=0.1, stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length', y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length', y='sepal_width', c='sepal_width') # c is for colour
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length', y='sepal_width', c='sepal_width', s=30) # s is for size
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length', y='sepal_width', c='sepal_width', s=df['sepal_length']*10) # s is for size
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.hexbin(x='sepal_length', y='sepal_width', gridsize=15) # gridsize is for size
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.hexbin(x='sepal_length', y='sepal_width', gridsize=15, cmap='viridis') # cmap is for colour and themes
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
from mpl_toolkits import mplot3d

# %%
# To plot 3D graph we need 3 axis x, y and z
x=np.linspace(-1,6,30) # 30 datapoints between -1 to 6
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y=np.linspace(-1,6,30) # 30 datapoints between -1 to 6
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z=x+y
z
# Out:
# array([-2.        , -1.51724138, -1.03448276, -0.55172414, -0.06896552,
#         0.4137931 ,  0.89655172,  1.37931034,  1.86206897,  2.34482759,
#         2.82758621,  3.31034483,  3.79310345,  4.27586207,  4.75862069,
#         5.24137931,  5.72413793,  6.20689655,  6.68965517,  7.17241379,
#         7.65517241,  8.13793103,  8.62068966,  9.10344828,  9.5862069 ,
#        10.06896552, 10.55172414, 11.03448276, 11.51724138, 12.        ])

# %%
ax=plt.axes(projection='3d') # for 3D
ax.plot3D(x,y,z)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
# Out:
# Text(0.5, 0, 'z-axis')

# %%
ax=plt.axes(projection='3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_width'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_width')
# Out:
# Text(0.5, 0, 'petal_width')

# %%
df.plot(figsize=(10,20)) # figsize is size of the graph
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10)) # barh for horizontal
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(20,10), color='#143E40', alpha=.9) 
# alpha is colour density and color='#143E40' is hexadesimal colour value
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="71276c3b-c20d-45ff-bd6b-87a61bceef49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='sepal_width', kind='scatter', mode='markers')
# Out:
# <div>                            <div id="6d6691c2-1506-4ffc-b90b-856e601bc9da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='sepal_width', kind='scatter', mode='markers')
# Out:
# <div>                            <div id="0e62ec72-defa-4f82-a2f6-da13bf9f7790" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='sepal_width', z='petal_length', kind='bubble3d', size='sepal_length')
# Out:
# <div>                            <div id="204109a0-32f5-4f6c-93ef-8c21694f03d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1=sns.load_dataset('tips')
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(x='total_bill',y='tip',kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x='total_bill',y='tip',kind='scatter', mode='markers')
# Out:
# <div>                            <div id="9cd2b2f3-6615-4a51-86a2-785c0665a8b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x='total_bill',y='tip',kind='scatter', data=df1, hue='time', style='sex') # hue is for cateogery
# style is for grouping

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',kind='scatter', data=df1, hue='size', style='size')

# %%
sns.relplot(x='total_bill',y='tip',kind='scatter', data=df1, col='time') 
# col will create seprate graphs

# %%
sns.relplot(x='sepal_length',y='sepal_width',kind='scatter', data=df, col='species')

# %%
sns.relplot(x='total_bill',y='tip',kind='scatter', data=df1, col='day')

# %%
sns.catplot(x='day',y='total_bill',data=df1)
# catplot is for cateogrical plot

# %%
sns.pairplot(data=df1)

# %%
sns.pairplot(data=df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="9a8c13f5-7747-467c-be37-a14303910541" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x=df1.total_bill, y=df1.tip)

# %%
sns.jointplot(x=df1.total_bill, y=df1.tip, kind='hex')

# %%
sns.pairplot(data=df1)

# %%
sns.regplot(x=df1.total_bill, y=df1.tip)
sns.set(rc={'figure.figsize':(20,10)})

# %%
import plotly.express as px
df = px.data.iris()
df["e"] = df["sepal_width"]/100
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", error_x="e", error_y="e")
fig.show()
# Out:
# <div>                            <div id="23f51c36-b7d0-4ee5-85ff-f42837d86ce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23f51c36-b7d0-4ee5-85ff-f42837d86ce0")) {                    Plotly.newPlot(                        "23f51c36-b7d0-4ee5-85ff-f42837d86ce0",                        [{"error_x":{"array":[0.035,0.03,0.032,0.031,0.036000000000000004,0.039,0.034,0.034,0.028999999999999998,0.031,0.037000000000000005,0.034,0.03,0.03,0.04,0.044000000000000004,0.039,0.035,0.038,0.038,0.034,0.037000000000000005,0.036000000000000004,0.033,0.034,0.03,0.034,0.035,0.034,0.032,0.031,0.034,0.040999999999999995,0.042,0.031,0.032,0.035,0.031,0.03,0.034,0.035,0.023,0.032,0.035,0.038,0.03,0.038,0.032,0.037000000000000005,0.033]},"error_y":{"array":[0.035,0.03,
# ...

# %%
import plotly.express as px
fig = px.bar(df1, x="sex", y="total_bill", color="smoker",barmode="group")
fig.show()
# Out:
# <div>                            <div id="87d59171-9a78-4f6e-86d7-e58ee08c4f49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87d59171-9a78-4f6e-86d7-e58ee08c4f49")) {                    Plotly.newPlot(                        "87d59171-9a78-4f6e-86d7-e58ee08c4f49",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...

# %%
cufflinks - https://github.com/santosjorge/cufflinks
plotly - https://plotly.com/python/plotly-express/
seaborn - https://seaborn.pydata.org/index.html
matplotlib - https://matplotlib.org/stable/index.html
